# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/f-rmula-de-her-n-martinpacios-1/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
ladoA = int (input ("introduce el valor de el lado a del triángulo:"))
ladoB = int (input ("introduce el valor de el lado b del triángulo:"))
ladoC = int (input ("introduce el valor de el lado c del triángulo:"))

s = (ladoA + ladoB + ladoC)/ 2

a = (s * (s - ladoA) * (s - ladoB) * (s - ladoC)) ** 0.5

print ("El semiperimetro del triangulo es:", s)
print ("El area del triangulo es:", a)
# Out:
# KeyboardInterrupt
